# %% [markdown]
# ### We are going to use the different libraries in this :
# * Pandas for the data filtering & merging purpose
# * Seaborn and Matplotlib for Data Visualization

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
print(pd.__version__)
# Out:
# 2.2.2

# %% [markdown]
# #### ---> Loading the Dataset 1 for processing

# %%
data_1 = pd.read_csv("dataset_1.csv")
data_1
# Out:
#      instant      dteday  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 0          1  01-01-2011       1   0     1   0    False        6           1
# 1          2  01-01-2011       1   0     1   1    False        6           1
# 2          3  01-01-2011       1   0     1   2    False        6           1
# 3          4  01-01-2011       1   0     1   3    False        6           1
# 4          5  01-01-2011       1   0     1   4    False        6           1
# ..       ...         ...     ...  ..   ...  ..      ...      ...         ...
# 605      606  28-01-2011       1   0     1  11    False        5           3
# 606      607  28-01-2011       1   0     1  12    False        5           3
# 607      608  28-01-2011       1   0     1  13    False        5           3
# 608      609  28-01-2011       1   0     1  14    False        5           3
# 609      610  28-01-2011       1   0     1  15    False        5           2
#
#      temp
# 0    0.24
# 1    0.22
# ...

# %% [markdown]
# #### ---> There are null values in our Dataset 1 hence used the Dropna functionality of pandas to drop the null values in dataset 1
# #### ---> Inplace = True useful to make the chnages in out original Dataset 1

# %%
data_1.dropna(inplace = True)
data_1
# Out:
#      instant      dteday  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 0          1  01-01-2011       1   0     1   0    False        6           1
# 1          2  01-01-2011       1   0     1   1    False        6           1
# 2          3  01-01-2011       1   0     1   2    False        6           1
# 3          4  01-01-2011       1   0     1   3    False        6           1
# 4          5  01-01-2011       1   0     1   4    False        6           1
# ..       ...         ...     ...  ..   ...  ..      ...      ...         ...
# 605      606  28-01-2011       1   0     1  11    False        5           3
# 606      607  28-01-2011       1   0     1  12    False        5           3
# 607      608  28-01-2011       1   0     1  13    False        5           3
# 608      609  28-01-2011       1   0     1  14    False        5           3
# 609      610  28-01-2011       1   0     1  15    False        5           2
#
#      temp
# 0    0.24
# 1    0.22
# ...

# %% [markdown]
# #### ---> We have only one unique value in Year & Month column, so dropped that column for better understanding of the data

# %%
filtered_1 = data_1[["instant", "dteday", "season", "hr", "holiday", "weekday", "weathersit", "temp"]]
filtered_1
# Out:
#      instant      dteday  season  hr  holiday  weekday  weathersit  temp
# 0          1  01-01-2011       1   0    False        6           1  0.24
# 1          2  01-01-2011       1   1    False        6           1  0.22
# 2          3  01-01-2011       1   2    False        6           1  0.22
# 3          4  01-01-2011       1   3    False        6           1  0.24
# 4          5  01-01-2011       1   4    False        6           1  0.24
# ..       ...         ...     ...  ..      ...      ...         ...   ...
# 605      606  28-01-2011       1  11    False        5           3  0.18
# 606      607  28-01-2011       1  12    False        5           3  0.18
# 607      608  28-01-2011       1  13    False        5           3  0.18
# 608      609  28-01-2011       1  14    False        5           3  0.22
# 609      610  28-01-2011       1  15    False        5           2  0.20
#
# [610 rows x 8 columns]

# %% [markdown]
# #### ---> Now we are going to visualize our dataset 1 which was filtered, for the visualization we are going to use the Seaborn and Matplotlib libraries
# * We are doing the visulization using the Histogram for the Temeprature

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 4))
sns.histplot(filtered_1['temp'], kde=True)
plt.title("Temperature for different Dates")
plt.xlabel("Normalized Temperature")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# #### --->Loading the Dataset 2 for processing

# %%
data_2 = pd.read_csv("dataset_2.csv")
data_2
# Out:
#      Unnamed: 0  instant   atemp   hum  windspeed  casual  registered  cnt
# 0             0        1  0.2879  0.81     0.0000       3          13   16
# 1             1        2  0.2727  0.80     0.0000       8          32   40
# 2             2        3  0.2727  0.80     0.0000       5          27   32
# 3             3        4  0.2879  0.75     0.0000       3          10   13
# 4             4        5  0.2879  0.75     0.0000       0           1    1
# ..          ...      ...     ...   ...        ...     ...         ...  ...
# 605         605      606  0.2121  0.93     0.1045       0          30   30
# 606         606      607  0.2121  0.93     0.1045       1          28   29
# 607         607      608  0.2121  0.93     0.1045       0          31   31
# 608         608      609  0.2727  0.80     0.0000       2          36   38
# 609         609      610  0.2576  0.86     0.0000       1          40   41
#
# [610 rows x 8 columns]

# %% [markdown]
# #### ---> There are null values in our Dataset 2 hence using the Dropna to drop the null values
# #### ---> Inplace = True useful to make the chnages in out original Dataset 2

# %%
data_2.dropna(inplace = True)
data_2
# Out:
#      Unnamed: 0  instant   atemp   hum  windspeed  casual  registered  cnt
# 0             0        1  0.2879  0.81     0.0000       3          13   16
# 1             1        2  0.2727  0.80     0.0000       8          32   40
# 2             2        3  0.2727  0.80     0.0000       5          27   32
# 3             3        4  0.2879  0.75     0.0000       3          10   13
# 4             4        5  0.2879  0.75     0.0000       0           1    1
# ..          ...      ...     ...   ...        ...     ...         ...  ...
# 605         605      606  0.2121  0.93     0.1045       0          30   30
# 606         606      607  0.2121  0.93     0.1045       1          28   29
# 607         607      608  0.2121  0.93     0.1045       0          31   31
# 608         608      609  0.2727  0.80     0.0000       2          36   38
# 609         609      610  0.2576  0.86     0.0000       1          40   41
#
# [599 rows x 8 columns]

# %% [markdown]
# #### ---> All columns have mutliple uniques values in dataset 2, so we need  all the columns of dataset2 so dropping only Unnamed column which shows the Serial number

# %%
filtered_2 = data_2[["instant", "atemp", "hum", "windspeed", "casual", "registered", "cnt"]]
filtered_2
# Out:
#      instant   atemp   hum  windspeed  casual  registered  cnt
# 0          1  0.2879  0.81     0.0000       3          13   16
# 1          2  0.2727  0.80     0.0000       8          32   40
# 2          3  0.2727  0.80     0.0000       5          27   32
# 3          4  0.2879  0.75     0.0000       3          10   13
# 4          5  0.2879  0.75     0.0000       0           1    1
# ..       ...     ...   ...        ...     ...         ...  ...
# 605      606  0.2121  0.93     0.1045       0          30   30
# 606      607  0.2121  0.93     0.1045       1          28   29
# 607      608  0.2121  0.93     0.1045       0          31   31
# 608      609  0.2727  0.80     0.0000       2          36   38
# 609      610  0.2576  0.86     0.0000       1          40   41
#
# [599 rows x 7 columns]

# %% [markdown]
# #### ---> Now we are going to visualize the dataset 2 with the help of Matplotlib Library
# * Here we are taking the three different parameters in one Plot
# * The line plot help use to understand the trend of Count, Casuality and Registered users in one Plot

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 6))
plt.plot(filtered_2['instant'], filtered_2['cnt'], label='Total Count (cnt)', color='blue')
plt.plot(filtered_2['instant'], filtered_2['casual'], label='Casuality', color='orange')
plt.plot(filtered_2['instant'], filtered_2['registered'], label='Registered Users', color='green')
plt.xlabel('Time (instant)')
plt.ylabel('User Count')
plt.title('User Counts Over Time')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(8, 6))
scatter = plt.scatter(filtered_2["hum"], filtered_2["windspeed"], c=filtered_2["cnt"], cmap='viridis', alpha=0.7, edgecolors='w')
plt.title("Humidity vs Windspeed (colored by Total Count)")
plt.xlabel("Humidity")
plt.ylabel("Windspeed")
plt.colorbar(scatter, label="Total Count (cnt)")
plt.grid(True)
plt.show()

# %% [markdown]
# #### ---> Now we have to merge the two different data in one, for that we can use the Merge function of Pandas.
# * In our Two dataset we have common column Instant, so we use Instant to merge the two different dataset
# * We can add the dataset to the left or right side of the dataset, here I have use Right to add the dataset2 at the right side of the dataset1
# * to_string() of Pandas used to print all the Rows and Columns of dataset

# %%
merged_data = pd.merge(filtered_1, filtered_2, on = "instant", how = "right")
print(merged_data.to_string())
# Out:
#      instant      dteday  season  hr  holiday  weekday  weathersit  temp   atemp   hum  windspeed  casual  registered  cnt
# 0          1  01-01-2011       1   0    False        6           1  0.24  0.2879  0.81     0.0000       3          13   16
# 1          2  01-01-2011       1   1    False        6           1  0.22  0.2727  0.80     0.0000       8          32   40
# 2          3  01-01-2011       1   2    False        6           1  0.22  0.2727  0.80     0.0000       5          27   32
# 3          4  01-01-2011       1   3    False        6           1  0.24  0.2879  0.75     0.0000       3          10   13
# 4          5  01-01-2011       1   4    False        6           1  0.24  0.2879  0.75     0.0000       0           1    1
# 5          6  01-01-2011       1   5    False        6           2  0.24  0.2576  0.75     0.0896       0           1    1
# 6          7  01-01-2011       1   6    False        6           1  0.22  0.2727  0.80     0.0000       2           0    2
# ...

# %% [markdown]
# #### ---> Here we are going to visualize the Merged dataset which we have made from datasert 1 and dataset 2 :
# * Taking the Bar chat here for comparing the average Registration of bikes per hous
# * Take the data as Rental bike for bettter understanding

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Group by hour and sum the total counts
hourly_counts = merged_data.groupby('hr')['cnt'].sum().reset_index()

# Set the plot style
sns.set(style="whitegrid")

# Plot
plt.figure(figsize=(12, 6))
sns.barplot(data=hourly_counts, x='hr', y='cnt', palette="Blues_d")

plt.title("Total Bike Rentals by Hour")
plt.xlabel("Hour of the Day")
plt.ylabel("Total Rentals (cnt)")
plt.xticks(range(0, 24))
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Dimple\AppData\Local\Temp\ipykernel_14980\2685040334.py:13: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=hourly_counts, x='hr', y='cnt', palette="Blues_d")

# %% [markdown]
# #### ---> Loading the Dataset 3 for processing

# %%
data_3 = pd.read_csv("dataset_3.csv")
data_3
# Out:
#      instant      dteday  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 0        620  29-01-2011       1   0     1   1    False        6           1
# 1        621  29-01-2011       1   0     1   2    False        6           1
# 2        622  29-01-2011       1   0     1   3    False        6           1
# 3        623  29-01-2011       1   0     1   4    False        6           1
# 4        624  29-01-2011       1   0     1   6    False        6           1
# ..       ...         ...     ...  ..   ...  ..      ...      ...         ...
# 385      615  28-01-2011       1   0     1  20    False        5           2
# 386      616  28-01-2011       1   0     1  21    False        5           2
# 387      617  28-01-2011       1   0     1  22    False        5           1
# 388      618  28-01-2011       1   0     1  23    False        5           1
# 389      619  29-01-2011       1   0     1   0    False        6           1
#
# ...

# %% [markdown]
# #### --> There are null values in our Dataset 3 hence using the Dropna to drop the null values
# #### --> Inplace = True useful to make the chnages in out original Dataset

# %%
data_3.dropna(inplace = True)
data_3
# Out:
#      instant      dteday  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 0        620  29-01-2011       1   0     1   1    False        6           1
# 1        621  29-01-2011       1   0     1   2    False        6           1
# 2        622  29-01-2011       1   0     1   3    False        6           1
# 3        623  29-01-2011       1   0     1   4    False        6           1
# 4        624  29-01-2011       1   0     1   6    False        6           1
# ..       ...         ...     ...  ..   ...  ..      ...      ...         ...
# 385      615  28-01-2011       1   0     1  20    False        5           2
# 386      616  28-01-2011       1   0     1  21    False        5           2
# 387      617  28-01-2011       1   0     1  22    False        5           1
# 388      618  28-01-2011       1   0     1  23    False        5           1
# 389      619  29-01-2011       1   0     1   0    False        6           1
#
# ...

# %% [markdown]
# #### ---> Here in Dataset 3, Year & Month column has only one Unique value hence drop that columns so can have filtered dataset 3

# %%
filtered_3 = data_3[["instant", "dteday", "season", "hr", "holiday", "weekday", "weathersit", "temp", "atemp", "hum", "windspeed", "casual", "registered", "cnt"]]
filtered_3
# Out:
#      instant      dteday  season  hr  holiday  weekday  weathersit  temp  \
# 0        620  29-01-2011       1   1    False        6           1  0.22
# 1        621  29-01-2011       1   2    False        6           1  0.22
# 2        622  29-01-2011       1   3    False        6           1  0.20
# 3        623  29-01-2011       1   4    False        6           1  0.16
# 4        624  29-01-2011       1   6    False        6           1  0.16
# ..       ...         ...     ...  ..      ...      ...         ...   ...
# 385      615  28-01-2011       1  20    False        5           2  0.24
# 386      616  28-01-2011       1  21    False        5           2  0.22
# 387      617  28-01-2011       1  22    False        5           1  0.24
# 388      618  28-01-2011       1  23    False        5           1  0.24
# 389      619  29-01-2011       1   0    False        6           1  0.22
#
#       atemp   hum  windspeed  casual  registered  cnt
# ...

# %% [markdown]
# #### ---> The line chart is mostly used to show the trend over time, here also we are using the line chat for the same
# * we are takin two different columns (Casual and Registered) for showing the trend over time
# * Plot showing the average difference that how many vehicles registred and the what are the casual user of the vehicle per hour of a day

# %%
plt.figure(figsize=(12,6))
sns.lineplot(data=filtered_3, x="hr", y="casual", estimator="mean", label="Casual User", errorbar=None)
sns.lineplot(data=filtered_3, x="hr", y="registered", estimator="mean", label="Registered User", errorbar=None)
plt.title("Average Casual vs Registered Users by Hour")
plt.xlabel("Hour of Day")
plt.ylabel("Average Users")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ### The MASTER DATASET
# #### ---> The Master dataset is made after filtering the 3 different dataset
# #### ---> Here I have used the Concate function of Pandas Library to concate the Two different dataset (i.g Merged dataset which made from dataset1 & dataset2 and the filtered dataset 3)

# %%
master_data = pd.concat([merged_data, filtered_3], ignore_index=True)
master_data
# Out:
#      instant      dteday  season  hr  holiday  weekday  weathersit  temp  \
# 0          1  01-01-2011       1   0    False        6           1  0.24
# 1          2  01-01-2011       1   1    False        6           1  0.22
# 2          3  01-01-2011       1   2    False        6           1  0.22
# 3          4  01-01-2011       1   3    False        6           1  0.24
# 4          5  01-01-2011       1   4    False        6           1  0.24
# ..       ...         ...     ...  ..      ...      ...         ...   ...
# 984      615  28-01-2011       1  20    False        5           2  0.24
# 985      616  28-01-2011       1  21    False        5           2  0.22
# 986      617  28-01-2011       1  22    False        5           1  0.24
# 987      618  28-01-2011       1  23    False        5           1  0.24
# 988      619  29-01-2011       1   0    False        6           1  0.22
#
#       atemp   hum  windspeed  casual  registered  cnt
# ...

# %% [markdown]
# #### ---> From the Master data we are going to find the Skewness , Kurtosis and the Outliers of the data
# * Using the Numpy and Scipy.stats we can do the different calculation, Matplotlib and Seaborn used for making the plot
# * Here the Skewness, Kutrosis and Outliers calculated for all the different columns
# * BoxPlot made for the clear visualization of Outliers
# * For loop used for iterating each columns of having different data

# %%
import pandas as pd
import numpy as np
from scipy.stats import skew, kurtosis
import matplotlib.pyplot as plt
import seaborn as sns

# Numerical columns to analyze
num_cols = ['temp', 'atemp', 'hum', 'windspeed', 'casual', 'registered', 'cnt']

# Loop through each numerical column
for col in num_cols:
    data = master_data[col].dropna()
    
    # Skewness and Kurtosis
    sk = skew(data)
    kt = kurtosis(data)
    print(f"\nColumn: {col}")
    print(f"  Skewness: {sk:.4f}")
    print(f"  Kurtosis: {kt:.4f}")
    
    # IQR and Outlier Detection
    Q1 = data.quantile(0.25)
    Q3 = data.quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    outliers = data[(data < lower_bound) | (data > upper_bound)]
    print(f"  IQR: {IQR:.4f}")
    print(f"  Number of outliers: {outliers.count()}")
    
    # Boxplot
    plt.figure(figsize=(8, 4))
    sns.boxplot(x=data)
    plt.title(f'Boxplot of {col}')
    plt.xlabel(col)
    plt.show()
# Out:
# Column: temp
#   Skewness: 0.5057
#   Kurtosis: 0.7176
#   IQR: 0.0800
#   Number of outliers: 62
# Column: atemp
#   Skewness: 0.4279
#   Kurtosis: 0.6614
#   IQR: 0.0909
#   Number of outliers: 41
# Column: hum
#   Skewness: 0.4425
#   Kurtosis: -0.7088
#   IQR: 0.2600
#   Number of outliers: 0
# Column: windspeed
#   Skewness: 0.4401
#   Kurtosis: -0.2062
#   IQR: 0.1791
#   Number of outliers: 4
# Column: casual
#   Skewness: 3.4131
#   Kurtosis: 14.9990
#   IQR: 6.0000
#   Number of outliers: 66
# Column: registered
#   Skewness: 1.2854
#   Kurtosis: 1.5927
#   IQR: 60.0000
#   Number of outliers: 42
# Column: cnt
#   Skewness: 1.1272
#   Kurtosis: 0.9847
#   IQR: 68.0000
#   Number of outliers: 27

# %% [markdown]
# #### ==> TO know the Correlation of Average Temperature during the Weekday and Hours HeatMap is the best
# * Take the Average of Temperature by Hour and Weekday during whole season
# * Colorbar beside the Plot useful to know the exect temprature, Blue colur used for low Temperature while Red color used for high Temperature

# %%
pivot_temp = master_data.pivot_table(index='weekday', columns='hr', values='temp', aggfunc='mean')

plt.figure(figsize=(12, 6))
sns.heatmap(pivot_temp, cmap="coolwarm", annot=False)
plt.title("Average Temperature by Hour and Weekday")
plt.xlabel("Hour")
plt.ylabel("Weekday (Starting from Sunday as 0)")
plt.show()

# %% [markdown]
# #### ---> For the Exporting of data in Master Data, to_csv functionality of Pandas is used
# * Index = False used to remove the index number from the dataset

# %%
master_file = master_data.to_csv("Master_File.csv", index=False)
master_file
